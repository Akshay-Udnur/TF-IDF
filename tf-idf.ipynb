# %%
# Out:
# There are 3041 reviews in this training set

# %%
import numpy as np
 
sentences = ["The iPhone battery life is exceptional, easily lasting throughout the day even with heavy usage.",
             "The camera quality on the iPhone is outstanding, capturing stunning photos and videos in various lighting conditions.",
             "The A15 Bionic chip in iPhone delivers remarkable performance, ensuring smooth multitasking and fast app responsiveness.",
             "The design of the iPhone feels sleek and premium, offering an excellent user experience.",
             "The new features like Cinematic mode add a creative touch to the iPhone camera, enhancing its capabilities.",
             "I am impressed with the display quality of the iPhone, providing crisp and vibrant visuals."]
 

class TF_IDF():
    def __init__(self,sentences):
        # First remove punctuations and also make all the words in small letters.
        sentences = [i.replace(",","") for i in sentences]
        sentences = [i.replace(".","") for i in sentences]
        sentences = [i.lower() for i in sentences]
        self.sentences = sentences
        
    def TF(self):
        out = {}
        for sentence in self.sentences:
            tf = {}
            for i in sentence.split():
                tf[i] = sentence.count(i)/len(sentence.split())
            out[sentence]= tf
        return out
    
    def IDF(self):
        out = {}
        for sentence in self.sentences:
            idf = {}
            for i in sentence.split():
                count = 0
                for j in self.sentences:
                    if i in j:
                        count+=1
                idf[i] = np.log(len(self.sentences)/count)
            out[sentence] = idf
        return out
    
    def TFIDF(self):
        out = {}
        tf = self.TF()
        idf = self.IDF()
        for sentence in self.sentences:
            tf_sent = tf[sentence]
            idf_sent = idf[sentence]
            tfidf = {}
            for i in tf_sent:
                tfidf[i]=tf_sent[i]*idf_sent[i]
            out[sentence] = tfidf
        return out

# %%
temp = TF_IDF(sentences)

# %%
temp.TFIDF()
# Out:
# {'the iphone battery life is exceptional easily lasting throughout the day even with heavy usage': {'the': 0.0,
#   'iphone': 0.0,
#   'battery': 0.11945063128187033,
#   'life': 0.11945063128187033,
#   'is': 0.046209812037329684,
#   'exceptional': 0.11945063128187033,
#   'easily': 0.11945063128187033,
#   'lasting': 0.11945063128187033,
#   'throughout': 0.11945063128187033,
#   'day': 0.11945063128187033,
#   'even': 0.11945063128187033,
#   'with': 0.07324081924454065,
#   'heavy': 0.11945063128187033,
#   'usage': 0.11945063128187033},
#  'the camera quality on the iphone is outstanding capturing stunning photos and videos in various lighting conditions': {'the': 0.0,
#   'camera': 0.06462425227459469,
#   'quality': 0.06462425227459469,
#   'on': 0.0,
#   'iphone': 0.0,
#   'is': 0.04077336356234972,
#   'outstanding': 0.1053976158369444,
#   'capturing': 0.1053976158369444,
#   'stunning': 0.1053976158369444,
#   'photos': 0.1053976158369444,
#   'and': 0.04770177742448993,
#   'videos': 0.1053976158369444,
#   'in': 0.0,
#   'various': 0.1053976158369444,
#   'lighting': 0.1053976158369444,
#   'conditions': 0.1053976158369444},
#  'the a15 bionic chip in iphone delivers remarkable performance ensuring smooth multitasking and fast app responsiveness': {'the': 0.0,
#   'a15': 0.11198496682675343,
#   'bionic': 0.11198496682675343,
#   'chip': 0.11198496682675343,
#   'in': 0.0,
#   'iphone': 0.0,
#   'delivers': 0.11198496682675343,
#   'remarkable': 0.11198496682675343,
#   'performance': 0.11198496682675343,
#   'ensuring': 0.11198496682675343,
#   'smooth': 0.11198496682675343,
#   'multitasking': 0.11198496682675343,
#   'and': 0.025341569256760274,
#   'fast': 0.11198496682675343,
#   'app': 0.11198496682675343,
#   'responsiveness': 0.11198496682675343},
#  'the design of the iphone feels sleek and premium offering an excellent user experience': {'the': 0.0,
#   'design': 0.12798281923057533,
#   'of': 0.15694461266687282,
#   'iphone': 0.0,
#   'feels': 0.12798281923057533,
#   'sleek': 0.12798281923057533,
#   'and': 0.028961793436297456,
#   'premium': 0.12798281923057533,
#   'offering': 0.12798281923057533,
#   'an': 0.026045936684850654,
#   'excellent': 0.12798281923057533,
#   'user': 0.12798281923057533,
#   'experience': 0.12798281923057533},
#  'the new features like cinematic mode add a creative touch to the iphone camera enhancing its capabilities': {'the': 0.0,
#   'new': 0.1053976158369444,
#   'features': 0.1053976158369444,
#   'like': 0.1053976158369444,
#   'cinematic': 0.1053976158369444,
#   'mode': 0.1053976158369444,
#   'add': 0.1053976158369444,
#   'a': 0.0,
#   'creative': 0.1053976158369444,
#   'touch': 0.1053976158369444,
#   'to': 0.12924850454918937,
#   'iphone': 0.0,
#   'camera': 0.06462425227459469,
#   'enhancing': 0.1053976158369444,
#   'its': 0.1053976158369444,
#   'capabilities': 0.1053976158369444},
#  'i am impressed with the display quality of the iphone providing crisp and vibrant visuals': {'i': 0.0,
#   'am': 0.046209812037329684,
#   'impressed': 0.11945063128187033,
#   'with': 0.07324081924454065,
#   'the': 0.0,
#   'display': 0.11945063128187033,
#   'quality': 0.07324081924454065,
#   'of': 0.07324081924454065,
#   'iphone': 0.0,
#   'providing': 0.11945063128187033,
#   'crisp': 0.11945063128187033,
#   'and': 0.02703100720721096,
#   'vibrant': 0.11945063128187033,
#   'visuals': 0.11945063128187033}}

# %%
temp.IDF()
# Out:
# {'the iphone battery life is exceptional easily lasting throughout the day even with heavy usage': {'the': 0.0,
#   'iphone': 0.0,
#   'battery': 1.791759469228055,
#   'life': 1.791759469228055,
#   'is': 0.6931471805599453,
#   'exceptional': 1.791759469228055,
#   'easily': 1.791759469228055,
#   'lasting': 1.791759469228055,
#   'throughout': 1.791759469228055,
#   'day': 1.791759469228055,
#   'even': 1.791759469228055,
#   'with': 1.0986122886681098,
#   'heavy': 1.791759469228055,
#   'usage': 1.791759469228055},
#  'the camera quality on the iphone is outstanding capturing stunning photos and videos in various lighting conditions': {'the': 0.0,
#   'camera': 1.0986122886681098,
#   'quality': 1.0986122886681098,
#   'on': 0.0,
#   'iphone': 0.0,
#   'is': 0.6931471805599453,
#   'outstanding': 1.791759469228055,
#   'capturing': 1.791759469228055,
#   'stunning': 1.791759469228055,
#   'photos': 1.791759469228055,
#   'and': 0.4054651081081644,
#   'videos': 1.791759469228055,
#   'in': 0.0,
#   'various': 1.791759469228055,
#   'lighting': 1.791759469228055,
#   'conditions': 1.791759469228055},
#  'the a15 bionic chip in iphone delivers remarkable performance ensuring smooth multitasking and fast app responsiveness': {'the': 0.0,
#   'a15': 1.791759469228055,
#   'bionic': 1.791759469228055,
#   'chip': 1.791759469228055,
#   'in': 0.0,
#   'iphone': 0.0,
#   'delivers': 1.791759469228055,
#   'remarkable': 1.791759469228055,
#   'performance': 1.791759469228055,
#   'ensuring': 1.791759469228055,
#   'smooth': 1.791759469228055,
#   'multitasking': 1.791759469228055,
#   'and': 0.4054651081081644,
#   'fast': 1.791759469228055,
#   'app': 1.791759469228055,
#   'responsiveness': 1.791759469228055},
#  'the design of the iphone feels sleek and premium offering an excellent user experience': {'the': 0.0,
#   'design': 1.791759469228055,
#   'of': 1.0986122886681098,
#   'iphone': 0.0,
#   'feels': 1.791759469228055,
#   'sleek': 1.791759469228055,
#   'and': 0.4054651081081644,
#   'premium': 1.791759469228055,
#   'offering': 1.791759469228055,
#   'an': 0.1823215567939546,
#   'excellent': 1.791759469228055,
#   'user': 1.791759469228055,
#   'experience': 1.791759469228055},
#  'the new features like cinematic mode add a creative touch to the iphone camera enhancing its capabilities': {'the': 0.0,
#   'new': 1.791759469228055,
#   'features': 1.791759469228055,
#   'like': 1.791759469228055,
#   'cinematic': 1.791759469228055,
#   'mode': 1.791759469228055,
#   'add': 1.791759469228055,
#   'a': 0.0,
#   'creative': 1.791759469228055,
#   'touch': 1.791759469228055,
#   'to': 1.0986122886681098,
#   'iphone': 0.0,
#   'camera': 1.0986122886681098,
#   'enhancing': 1.791759469228055,
#   'its': 1.791759469228055,
#   'capabilities': 1.791759469228055},
#  'i am impressed with the display quality of the iphone providing crisp and vibrant visuals': {'i': 0.0,
#   'am': 0.6931471805599453,
#   'impressed': 1.791759469228055,
#   'with': 1.0986122886681098,
#   'the': 0.0,
#   'display': 1.791759469228055,
#   'quality': 1.0986122886681098,
#   'of': 1.0986122886681098,
#   'iphone': 0.0,
#   'providing': 1.791759469228055,
#   'crisp': 1.791759469228055,
#   'and': 0.4054651081081644,
#   'vibrant': 1.791759469228055,
#   'visuals': 1.791759469228055}}

# %%
temp.TF()
# Out:
# {'the iphone battery life is exceptional easily lasting throughout the day even with heavy usage': {'the': 0.13333333333333333,
#   'iphone': 0.06666666666666667,
#   'battery': 0.06666666666666667,
#   'life': 0.06666666666666667,
#   'is': 0.06666666666666667,
#   'exceptional': 0.06666666666666667,
#   'easily': 0.06666666666666667,
#   'lasting': 0.06666666666666667,
#   'throughout': 0.06666666666666667,
#   'day': 0.06666666666666667,
#   'even': 0.06666666666666667,
#   'with': 0.06666666666666667,
#   'heavy': 0.06666666666666667,
#   'usage': 0.06666666666666667},
#  'the camera quality on the iphone is outstanding capturing stunning photos and videos in various lighting conditions': {'the': 0.11764705882352941,
#   'camera': 0.058823529411764705,
#   'quality': 0.058823529411764705,
#   'on': 0.23529411764705882,
#   'iphone': 0.058823529411764705,
#   'is': 0.058823529411764705,
#   'outstanding': 0.058823529411764705,
#   'capturing': 0.058823529411764705,
#   'stunning': 0.058823529411764705,
#   'photos': 0.058823529411764705,
#   'and': 0.11764705882352941,
#   'videos': 0.058823529411764705,
#   'in': 0.29411764705882354,
#   'various': 0.058823529411764705,
#   'lighting': 0.058823529411764705,
#   'conditions': 0.058823529411764705},
#  'the a15 bionic chip in iphone delivers remarkable performance ensuring smooth multitasking and fast app responsiveness': {'the': 0.0625,
#   'a15': 0.0625,
#   'bionic': 0.0625,
#   'chip': 0.0625,
#   'in': 0.1875,
#   'iphone': 0.0625,
#   'delivers': 0.0625,
#   'remarkable': 0.0625,
#   'performance': 0.0625,
#   'ensuring': 0.0625,
#   'smooth': 0.0625,
#   'multitasking': 0.0625,
#   'and': 0.0625,
#   'fast': 0.0625,
#   'app': 0.0625,
#   'responsiveness': 0.0625},
#  'the design of the iphone feels sleek and premium offering an excellent user experience': {'the': 0.14285714285714285,
#   'design': 0.07142857142857142,
#   'of': 0.14285714285714285,
#   'iphone': 0.07142857142857142,
#   'feels': 0.07142857142857142,
#   'sleek': 0.07142857142857142,
#   'and': 0.07142857142857142,
#   'premium': 0.07142857142857142,
#   'offering': 0.07142857142857142,
#   'an': 0.14285714285714285,
#   'excellent': 0.07142857142857142,
#   'user': 0.07142857142857142,
#   'experience': 0.07142857142857142},
#  'the new features like cinematic mode add a creative touch to the iphone camera enhancing its capabilities': {'the': 0.11764705882352941,
#   'new': 0.058823529411764705,
#   'features': 0.058823529411764705,
#   'like': 0.058823529411764705,
#   'cinematic': 0.058823529411764705,
#   'mode': 0.058823529411764705,
#   'add': 0.058823529411764705,
#   'a': 0.5882352941176471,
#   'creative': 0.058823529411764705,
#   'touch': 0.058823529411764705,
#   'to': 0.11764705882352941,
#   'iphone': 0.058823529411764705,
#   'camera': 0.058823529411764705,
#   'enhancing': 0.058823529411764705,
#   'its': 0.058823529411764705,
#   'capabilities': 0.058823529411764705},
#  'i am impressed with the display quality of the iphone providing crisp and vibrant visuals': {'i': 0.7333333333333333,
#   'am': 0.06666666666666667,
#   'impressed': 0.06666666666666667,
#   'with': 0.06666666666666667,
#   'the': 0.13333333333333333,
#   'display': 0.06666666666666667,
#   'quality': 0.06666666666666667,
#   'of': 0.06666666666666667,
#   'iphone': 0.06666666666666667,
#   'providing': 0.06666666666666667,
#   'crisp': 0.06666666666666667,
#   'and': 0.06666666666666667,
#   'vibrant': 0.06666666666666667,
#   'visuals': 0.06666666666666667}}

# %%
c
